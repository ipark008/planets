# %% [markdown]
# <a href="https://colab.research.google.com/github/ipark008/planets/blob/master/dftb_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:17
# 🔁 Restarting kernel...

# %% [markdown]
# Wait

# %%
import condacolab
condacolab.check()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-2-9ce5e157f4c4> in <cell line: 0>()
#       1 import condacolab
# ----> 2 condacolab.check()
#
# /usr/local/lib/python3.11/dist-packages/condacolab.py in check(prefix, verbose)
#     329     ), f"💥💔💥 PATH was not patched! Value: {os.environ['PATH']}"
#     330     assert (
# --> 331         f"{prefix}/lib" in os.environ["LD_LIBRARY_PATH"]
#     332     ), f"💥💔💥 LD_LIBRARY_PATH was not patched! Value: {os.environ['LD_LIBRARY_PATH']}"
#     333     if verbose:
#
# AssertionError: 💥💔💥 LD_LIBRARY_PATH was not patched! Value: /usr/local/nvidia/lib:/usr/local/nvidia/lib64

# %%
# !conda install  mamba -y -q
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - mamba
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2025.4.26  |       hbd8a1cb_0         149 KB  conda-forge
#     certifi-2025.4.26          |     pyhd8ed1ab_0         154 KB  conda-forge
#     conda-25.5.0               |  py311h38be061_0         1.2 MB  conda-forge
#     conda-libmamba-solver-25.4.0|     pyhd8ed1ab_0          41 KB  conda-forge
#     cpp-expected-1.1.0         |       hff21bea_1          24 KB  conda-forge
#     fmt-11.1.4                 |       h07f6e7f_1         187 KB  conda-forge
#     libcurl-8.12.1             |       h332b0f4_0         417 KB  conda-forge
#     libmamba-2.1.1             |       h430c389_0         2.0 MB  conda-forge
#     libmambapy-2.1.1           |  py311h952910f_0         615 KB  conda-forge
#     libsolv-0.7.32             |       h7955e40_2         467 KB  conda-forge
#     mamba-2.1.1                |       had4a41a_0         451 KB  conda-forge
#     nlohmann_json-3.11.3       |       he02047a_1         120 KB  conda-forge
#     openssl-3.5.0              |       h7b32b05_1         3.0 MB  conda-forge
#     simdjson-3.12.3            |       h84d6215_0         242 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         8.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   cpp-expected       conda-forge/linux-64::cpp-expected-1.1.0-hff21bea_1
#   nlohmann_json      conda-forge/linux-64::nlohmann_json-3.11.3-he02047a_1
#   simdjson           conda-forge/linux-64::simdjson-3.12.3-h84d6215_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge/linux-64::ca-certificates~ --> conda-forge/noarch::ca-certificates-2025.4.26-hbd8a1cb_0
#   certifi                           2024.12.14-pyhd8ed1ab_0 --> 2025.4.26-pyhd8ed1ab_0
#   conda                             24.11.2-py311h38be061_1 --> 25.5.0-py311h38be061_0
#   conda-libmamba-so~                    24.9.0-pyhd8ed1ab_0 --> 25.4.0-pyhd8ed1ab_0
#   fmt                                     11.0.2-h434a139_0 --> 11.1.4-h07f6e7f_1
#   libcurl                                 8.11.1-h332b0f4_0 --> 8.12.1-h332b0f4_0
#   libmamba                                1.5.12-h49b8a8d_0 --> 2.1.1-h430c389_0
#   libmambapy                         1.5.12-py311hb3373dd_0 --> 2.1.1-py311h952910f_0
#   libsolv                                 0.7.30-h3509ff9_0 --> 0.7.32-h7955e40_2
#   mamba                              1.5.12-py311h3072747_0 --> 2.1.1-had4a41a_0
#   openssl                                  3.4.0-h7b32b05_1 --> 3.5.0-h7b32b05_1
#
#
#
# Downloading and Extracting Packages:
# openssl-3.5.0        | 3.0 MB    | :   0% 0/1 [00:00<?, ?it/s]
# libmamba-2.1.1       | 2.0 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
# conda-25.5.0         | 1.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
# libmambapy-2.1.1     | 615 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# libsolv-0.7.32       | 467 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# mamba-2.1.1          | 451 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# libcurl-8.12.1       | 417 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# simdjson-3.12.3      | 242 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# fmt-11.1.4           | 187 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# certifi-2025.4.26    | 154 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 149 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# nlohmann_json-3.11.3 | 120 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# conda-libmamba-solve | 41 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# cpp-expected-1.1.0   | 24 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# openssl-3.5.0        | 3.0 MB    | :  22% 0.22073708623504767/1 [00:00<00:00,  2.19it/s]
# libmamba-2.1.1       | 2.0 MB    | :  45% 0.45409007232275966/1 [00:00<00:00,  4.53it/s]
#
# conda-25.5.0         | 1.2 MB    | :  55% 0.5530960481376943/1 [00:00<00:00,  5.24it/s]
#
#
# libmambapy-2.1.1     | 615 KB    | : 100% 1.0/1 [00:00<00:00,  9.37it/s]
#
#
# libmambapy-2.1.1     | 615 KB    | : 100% 1.0/1 [00:00<00:00,  9.37it/s]
#
#
#
#
# mamba-2.1.1          | 451 KB    | :   4% 0.03548225021223514/1 [00:00<00:03,  3.41s/it]
#
#
#
#
# mamba-2.1.1          | 451 KB    | : 100% 1.0/1 [00:00<00:00,  3.41s/it]
#
#
#
#
#
# libcurl-8.12.1       | 417 KB    | :   4% 0.038399250014648154/1 [00:00<00:03,  3.64s/it]
#
# conda-25.5.0         | 1.2 MB    | : 100% 1.0/1 [00:00<00:00,  5.24it/s]
#
#
#
#
#
# libcurl-8.12.1       | 417 KB    | : 100% 1.0/1 [00:00<00:00,  3.64s/it]
# libmamba-2.1.1       | 2.0 MB    | : 100% 1.0/1 [00:00<00:00,  4.53it/s]
#
#
#
#
#
#
# simdjson-3.12.3      | 242 KB    | :   7% 0.06603283102059898/1 [00:00<00:02,  2.66s/it]
#
#
#
#
#
#
# simdjson-3.12.3      | 242 KB    | : 100% 1.0/1 [00:00<00:00,  2.66s/it]
#
#
#
#
#
#
#
#
# certifi-2025.4.26    | 154 KB    | :  10% 0.1042239185750636/1 [00:00<00:01,  1.81s/it]
#
#
#
#
#
#
#
# fmt-11.1.4           | 187 KB    | :   9% 0.08570785882057533/1 [00:00<00:02,  2.22s/it]
#
#
#
#
#
#
#
#
# certifi-2025.4.26    | 154 KB    | : 100% 1.0/1 [00:00<00:00,  1.81s/it]
#
#
#
#
#
#
#
# fmt-11.1.4           | 187 KB    | : 100% 1.0/1 [00:00<00:00,  2.22s/it]
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 149 KB    | :  11% 0.10758915965669182/1 [00:00<00:01,  1.90s/it]
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 149 KB    | : 100% 1.0/1 [00:00<00:00,  1.90s/it]
#
#
#
#
#
#
#
#
#
#
# nlohmann_json-3.11.3 | 120 KB    | :  13% 0.133482153768443/1 [00:00<00:01,  1.60s/it]
#
#
#
#
#
#
#
#
#
#
# openssl-3.5.0        | 3.0 MB    | : 100% 1.0/1 [00:00<00:00,  4.58it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# cpp-expected-1.1.0   | 24 KB     | :  68% 0.6794675071538174/1 [00:00<00:00,  2.93it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# cpp-expected-1.1.0   | 24 KB     | : 100% 1.0/1 [00:00<00:00,  2.93it/s]
#
#
# libmambapy-2.1.1     | 615 KB    | : 100% 1.0/1 [00:00<00:00,  9.37it/s]
#
#
#
#
#
#
#
#
#
#
#
# conda-libmamba-solve | 41 KB     | :  39% 0.39023460759795164/1 [00:00<00:00,  1.61it/s]
#
#
#
#
#
#
#
#
#
#
#
# conda-libmamba-solve | 41 KB     | : 100% 1.0/1 [00:00<00:00,  1.61it/s]
#
#
#
# libsolv-0.7.32       | 467 KB    | : 100% 1.0/1 [00:00<00:00,  3.82it/s]
#
#
#
# libsolv-0.7.32       | 467 KB    | : 100% 1.0/1 [00:00<00:00,  3.82it/s]
#
#
#
#
# mamba-2.1.1          | 451 KB    | : 100% 1.0/1 [00:00<00:00,  4.11it/s]
#
#
#
#
# mamba-2.1.1          | 451 KB    | : 100% 1.0/1 [00:00<00:00,  4.11it/s]
#
#
#
#
#
# libcurl-8.12.1       | 417 KB    | : 100% 1.0/1 [00:00<00:00,  3.62it/s]
#
#
#
#
#
# libcurl-8.12.1       | 417 KB    | : 100% 1.0/1 [00:00<00:00,  3.62it/s]
# libmamba-2.1.1       | 2.0 MB    | : 100% 1.0/1 [00:00<00:00,  1.85it/s]
# libmamba-2.1.1       | 2.0 MB    | : 100% 1.0/1 [00:00<00:00,  1.85it/s]
#
#
#
#
#
#
# simdjson-3.12.3      | 242 KB    | : 100% 1.0/1 [00:00<00:00,  2.05it/s]
#
#
#
#
#
#
# simdjson-3.12.3      | 242 KB    | : 100% 1.0/1 [00:00<00:00,  2.05it/s]
#
#
#
#
#
#
#
#
# certifi-2025.4.26    | 154 KB    | : 100% 1.0/1 [00:00<00:00,  1.95it/s]
#
#
#
#
#
#
#
#
# certifi-2025.4.26    | 154 KB    | : 100% 1.0/1 [00:00<00:00,  1.95it/s]
#
#
#
#
#
#
#
# fmt-11.1.4           | 187 KB    | : 100% 1.0/1 [00:00<00:00,  1.84it/s]
#
#
#
#
#
#
#
# fmt-11.1.4           | 187 KB    | : 100% 1.0/1 [00:00<00:00,  1.84it/s]
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 149 KB    | : 100% 1.0/1 [00:00<00:00,  1.79it/s]
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 149 KB    | : 100% 1.0/1 [00:00<00:00,  1.79it/s]
#
# conda-25.5.0         | 1.2 MB    | : 100% 1.0/1 [00:00<00:00,  5.24it/s]
#
#
#
#
#
#
#
#
#
#
# nlohmann_json-3.11.3 | 120 KB    | : 100% 1.0/1 [00:00<00:00,  1.63it/s]
#
#
#
#
#
#
#
#
#
#
# nlohmann_json-3.11.3 | 120 KB    | : 100% 1.0/1 [00:00<00:00,  1.63it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# cpp-expected-1.1.0   | 24 KB     | : 100% 1.0/1 [00:00<00:00,  1.32it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# cpp-expected-1.1.0   | 24 KB     | : 100% 1.0/1 [00:00<00:00,  1.32it/s]
#
#
#
#
#
#
#
#
#
#
#
# conda-libmamba-solve | 41 KB     | : 100% 1.0/1 [00:00<00:00,  1.42it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done

# %%
# !mamba install 'dftbplus=*=nompi_*'
# Out:
# [+] 0.0s
# [+] 0.1s
# conda-forge/linux-64   1%
# conda-forge/noarch    ⣾  [+] 0.2s
# conda-forge/linux-64  10%
# conda-forge/noarch    16%[+] 0.3s
# conda-forge/linux-64  19%
# conda-forge/noarch    36%[+] 0.4s
# conda-forge/linux-64  25%
# conda-forge/noarch    49%[+] 0.5s
# conda-forge/linux-64  32%
# conda-forge/noarch    63%[+] 0.6s
# conda-forge/linux-64  37%
# conda-forge/noarch    70%[+] 0.7s
# conda-forge/linux-64  45%
# conda-forge/noarch    84%conda-forge/noarch
# [+] 0.8s
# conda-forge/linux-64  49%[+] 0.9s
# conda-forge/linux-64  62%[+] 1.0s
# conda-forge/linux-64  73%[+] 1.1s
# conda-forge/linux-64  84%[+] 1.2s
# conda-forge/linux-64  92%conda-forge/linux-64
#
# Pinned packages:
#
#   - python=3.11
#
# Pinned packages:
#
#   - python_abi[version="=3.11",build="*cp311*"]
#
# Pinned packages:
#
#   - cuda-version=12
#
# Pinned packages:
#
#   - python=3.11
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   Updating specs:
#
#    - dftbplus[build="nompi_*"]
#
#
#   Package              Version  Build                 Channel          Size
# ─────────────────────────────────────────────────────────────────────────────
#   Install:
# ─────────────────────────────────────────────────────────────────────────────
#
#   + arpack               3.8.0  nompi_h0baa96a_101    conda-forge     219kB
#   + chimes-calculator    1.0.2  h0c14de7_0            conda-forge     190kB
#   + dftbplus              24.1  nompi_h5d91ca9_100    conda-forge      11MB
#   + dftd4                3.6.0  hf49bc11_0            conda-forge     601kB
#   + fftw                3.3.10  nompi_hf1063bd_110    conda-forge       2MB
#   + gawk                 5.3.1  hcd3d067_0            conda-forge       1MB
#   + gmp                  6.3.0  hac33072_2            conda-forge     460kB
#   + gsl                    2.7  he838d99_0            conda-forge       3MB
#   + libasprintf         0.24.1  h8e693c7_0            conda-forge      53kB
#   + libblas              3.9.0  31_h59b9bed_openblas  conda-forge      17kB
#   + libcblas             3.9.0  31_he106b2a_openblas  conda-forge      17kB
#   + libgettextpo        0.24.1  h5888daf_0            conda-forge     171kB
#   + libgfortran         14.2.0  h69a702a_2            conda-forge      54kB
#   + libgfortran-ng      14.2.0  h69a702a_2            conda-forge      54kB
#   + libgfortran5        14.2.0  hf1ad2bd_2            conda-forge       1MB
#   + liblapack            3.9.0  31_h7ac8fdf_openblas  conda-forge      17kB
#   + libmbd              0.12.8  nompi_h9912f97_100    conda-forge     413kB
#   + libnegf              1.1.3  nompi_hfc7b0ff_101    conda-forge     560kB
#   + libopenblas         0.3.29  pthreads_h94d23a6_0   conda-forge       6MB
#   + mctc-lib             0.3.2  h3b12eaf_1            conda-forge     462kB
#   + mpfr                 4.2.1  h90cbb55_3            conda-forge     635kB
#   + plumed               2.9.2  nompi_hda5c677_100    conda-forge       4MB
#   + simple-dftd3         1.0.0  hd59d2e7_0            conda-forge     706kB
#   + tblite               0.3.0  hf49bc11_1            conda-forge       4MB
#   + toml-f               0.4.2  h3b12eaf_2            conda-forge     450kB
#
#   Summary:
#
#   Install: 25 packages
#
#   Total download: 38MB
#
# ─────────────────────────────────────────────────────────────────────────────
#
#
#
# Transaction starting
# [+] 0.0s
# Downloading        5%
# Extracting         0%[+] 0.1s
# Downloading  (5)   0%
# Extracting         0%libopenblas                                          5.9MB @   4.3MB/s  0.1s
# gsl                                                  3.4MB @ 294.0kB/s  0.1s
# [+] 0.2s
# Downloading  (5)  47%
# Extracting   (1)  ⣾  libgfortran5                                         1.5MB @  13.2MB/s  0.1s
# fftw                                                 2.1MB @  16.8MB/s  0.1s
# tblite                                               3.7MB @  13.1MB/s  0.2s
# [+] 0.3s
# Downloading  (5)  66%
# Extracting   (4)  ⣾  plumed                                               3.7MB @   9.4MB/s  0.3s
# gawk                                                 1.2MB @  10.7MB/s  0.1s
# mpfr                                               634.8kB @   9.4MB/s  0.1s
# simple-dftd3                                       706.2kB @   6.6MB/s  0.1s
# gmp                                                460.1kB @  ??.?MB/s  0.0s
# [+] 0.4s
# Downloading  (5)  84%
# Extracting   (8)  ⣾  dftbplus                                            10.9MB @  18.5MB/s  0.4s
# toml-f                                             450.3kB @  ??.?MB/s  0.0s
# libnegf                                            559.8kB @  ??.?MB/s  0.1s
# mctc-lib                                           462.3kB @  ??.?MB/s  0.1s
# libmbd                                             413.3kB @   2.0MB/s  0.1s
# [+] 0.5s
# Downloading  (4)  98%
# Extracting  (12)  ⣾  dftd4                                              601.4kB @   1.9MB/s  0.2s
# libgettextpo                                       171.2kB @  ??.?MB/s  0.0s
# arpack                                             219.4kB @   1.7MB/s  0.1s
# libgfortran-ng                                      53.8kB @ 934.4kB/s  0.1s
# libgfortran                                         53.7kB @  ??.?MB/s  0.0s
# libasprintf                                         53.1kB @  ??.?MB/s  0.0s
# chimes-calculator                                  189.6kB @   1.6MB/s  0.1s
# libblas                                             16.9kB @  ??.?MB/s  0.0s
# libcblas                                            16.8kB @  ??.?MB/s  0.0s
# [+] 0.6s
# Downloading  (1) 100%
# Extracting  (21)  ⣾  liblapack                                           16.8kB @  ??.?MB/s  0.0s
# [+] 0.7s
# Downloading      100%
# Extracting  (24)  ⣾  [+] 0.8s
# Downloading      100%
# Extracting  (25)  ⣾  [+] 0.9s
# Downloading      100%
# Extracting  (24)  ⣾  [+] 1.0s
# Downloading      100%
# Extracting  (24)  ⣾  [+] 1.1s
# Downloading      100%
# Extracting  (23)  ⣾  [+] 1.2s
# Downloading      100%
# Extracting  (23)  ⣾  [+] 1.3s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 1.4s
# Downloading      100%
# Extracting  (21)  ⣾  [+] 1.5s
# Downloading      100%
# Extracting  (21)  ⣾  [+] 1.6s
# Downloading      100%
# Extracting  (20)  ⣾  [+] 1.7s
# Downloading      100%
# Extracting  (19)  ⣾  [+] 1.8s
# Downloading      100%
# Extracting  (18)  ⣾  [+] 1.9s
# Downloading      100%
# Extracting  (17)  ⣾  [+] 2.0s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 2.1s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 2.2s
# Downloading      100%
# Extracting  (14)  ⣾  [+] 2.3s
# Downloading      100%
# Extracting  (10)  ⣾  [+] 2.4s
# Downloading      100%
# Extracting  (10)  ⣾  [+] 2.5s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 2.6s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 2.7s
# Downloading      100%
# Extracting   (2)  ⣾  Linking libgfortran5-14.2.0-hf1ad2bd_2
# Linking gmp-6.3.0-hac33072_2
# Linking libasprintf-0.24.1-h8e693c7_0
# Linking libgettextpo-0.24.1-h5888daf_0
# Linking libgfortran-14.2.0-h69a702a_2
# Linking mpfr-4.2.1-h90cbb55_3
# Linking toml-f-0.4.2-h3b12eaf_2
# Linking mctc-lib-0.3.2-h3b12eaf_1
# Linking libopenblas-0.3.29-pthreads_h94d23a6_0
# Linking libgfortran-ng-14.2.0-h69a702a_2
# Linking gawk-5.3.1-hcd3d067_0
# Linking libblas-3.9.0-31_h59b9bed_openblas
# Linking fftw-3.3.10-nompi_hf1063bd_110
# Linking chimes-calculator-1.0.2-h0c14de7_0
# Linking libcblas-3.9.0-31_he106b2a_openblas
# Linking liblapack-3.9.0-31_h7ac8fdf_openblas
# Linking simple-dftd3-1.0.0-hd59d2e7_0
# Linking gsl-2.7-he838d99_0
# Linking libnegf-1.1.3-nompi_hfc7b0ff_101
# Linking dftd4-3.6.0-hf49bc11_0
# Linking arpack-3.8.0-nompi_h0baa96a_101
# Linking libmbd-0.12.8-nompi_h9912f97_100
# Linking plumed-2.9.2-nompi_hda5c677_100
# Linking tblite-0.3.0-hf49bc11_1
# Linking dftbplus-24.1-nompi_h5d91ca9_100
#
# Transaction finished

# %%
# !mamba install dftbplus-tools dftbplus-python
# Out:
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
#
# Pinned packages:
#
#   - python=3.11
#
# Pinned packages:
#
#   - python_abi[version="=3.11",build="*cp311*"]
#
# Pinned packages:
#
#   - cuda-version=12
#
# Pinned packages:
#
#   - python=3.11
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   Updating specs:
#
#    - dftbplus-tools
#    - dftbplus-python
#
#
#   Package            Version  Build            Channel         Size
# ─────────────────────────────────────────────────────────────────────
#   Install:
# ─────────────────────────────────────────────────────────────────────
#
#   + dftbplus-python     24.1  pyhd8ed1ab_1     conda-forge     24kB
#   + dftbplus-tools      24.1  pyhd8ed1ab_1     conda-forge     40kB
#   + numpy              2.2.6  py311h5d046bc_0  conda-forge      9MB
#
#   Summary:
#
#   Install: 3 packages
#
#   Total download: 9MB
#
# ─────────────────────────────────────────────────────────────────────
#
#
#
# Transaction starting
# [+] 0.0s
# Downloading        5%
# Extracting         0%[+] 0.1s
# Downloading  (3)   1%
# Extracting         0%numpy                                                9.1MB @ 187.7kB/s  0.0s
# [+] 0.2s
# Downloading  (2) 100%
# Extracting   (1)  ⣾  [+] 0.3s
# Downloading  (2) 100%
# Extracting   (1)  ⣾  dftbplus-tools                                      40.5kB @  42.2kB/s  0.3s
# dftbplus-python                                     24.3kB @  ??.?MB/s  0.3s
# [+] 0.4s
# Downloading      100%
# Extracting   (3)  ⣾  [+] 0.5s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 0.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 0.7s
# Downloading      100%
# Extracting   (1)  ⣾  Linking numpy-2.2.6-py311h5d046bc_0
# warning  libmamba [numpy-2.2.6-py311h5d046bc_0] The following files were already present in the environment:
#     - bin/f2py
#     - bin/numpy-config
# Linking dftbplus-tools-24.1-pyhd8ed1ab_1
# warning  libmamba [dftbplus-tools-24.1-pyhd8ed1ab_1] The following files were already present in the environment:
#     - bin/makecube
# Linking dftbplus-python-24.1-pyhd8ed1ab_1
#
# Transaction finished

# %%
# !which dftb+
# Out:
# /usr/local/bin/dftb+

# %% [markdown]
# https://dftb.org/parameters/download.html

# %%
# !wget https://github.com/dftbparams/matsci/archive/refs/tags/v0.3.0.zip
# Out:
# --2025-05-28 01:12:45--  https://github.com/dftbparams/matsci/archive/refs/tags/v0.3.0.zip
# Resolving github.com (github.com)... 20.27.177.113
# Connecting to github.com (github.com)|20.27.177.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/dftbparams/matsci/zip/refs/tags/v0.3.0 [following]
# --2025-05-28 01:12:46--  https://codeload.github.com/dftbparams/matsci/zip/refs/tags/v0.3.0
# Resolving codeload.github.com (codeload.github.com)... 20.27.177.114
# Connecting to codeload.github.com (codeload.github.com)|20.27.177.114|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘v0.3.0.zip’
#
# v0.3.0.zip              [  <=>               ]   1.53M  6.65MB/s    in 0.2s
#
# 2025-05-28 01:12:46 (6.65 MB/s) - ‘v0.3.0.zip’ saved [1600906]

# %%
# !unzip v0.3.0.zip
# Out:
# Archive:  v0.3.0.zip
# 57016b4363fd6180f6edff662e5fbaa95276b4bd
#    creating: matsci-0.3.0/
#    creating: matsci-0.3.0/.github/
#    creating: matsci-0.3.0/.github/workflows/
#   inflating: matsci-0.3.0/.github/workflows/release.yml
#  extracting: matsci-0.3.0/CHANGELOG.md
#   inflating: matsci-0.3.0/LICENSE
#   inflating: matsci-0.3.0/README
#   inflating: matsci-0.3.0/RELEASE.md
#    creating: matsci-0.3.0/extras/
#   inflating: matsci-0.3.0/extras/wfc.hsd
#    creating: matsci-0.3.0/skfiles/
#   inflating: matsci-0.3.0/skfiles/Al-Al.skf
#   inflating: matsci-0.3.0/skfiles/Al-C.skf
#   inflating: matsci-0.3.0/skfiles/Al-Cu.skf
#   inflating: matsci-0.3.0/skfiles/Al-H.skf
#   inflating: matsci-0.3.0/skfiles/Al-Na.skf
#   inflating: matsci-0.3.0/skfiles/Al-O.skf
#   inflating: matsci-0.3.0/skfiles/Al-P.skf
#   inflating: matsci-0.3.0/skfiles/Al-Si.skf
#   inflating: matsci-0.3.0/skfiles/B-B.skf
#   inflating: matsci-0.3.0/skfiles/B-C.skf
#   inflating: matsci-0.3.0/skfiles/B-H.skf
#   inflating: matsci-0.3.0/skfiles/B-N.skf
#   inflating: matsci-0.3.0/skfiles/B-O.skf
#   inflating: matsci-0.3.0/skfiles/C-Al.skf
#   inflating: matsci-0.3.0/skfiles/C-B.skf
#   inflating: matsci-0.3.0/skfiles/C-C.skf
#   inflating: matsci-0.3.0/skfiles/C-H.skf
#   inflating: matsci-0.3.0/skfiles/C-N.skf
#   inflating: matsci-0.3.0/skfiles/C-O.skf
#   inflating: matsci-0.3.0/skfiles/C-P.skf
#   inflating: matsci-0.3.0/skfiles/C-Si.skf
#   inflating: matsci-0.3.0/skfiles/C-Ti.skf
#   inflating: matsci-0.3.0/skfiles/Cu-Al.skf
#   inflating: matsci-0.3.0/skfiles/Cu-Cu.skf
#   inflating: matsci-0.3.0/skfiles/Cu-H.skf
#   inflating: matsci-0.3.0/skfiles/Cu-Na.skf
#   inflating: matsci-0.3.0/skfiles/Cu-O.skf
#   inflating: matsci-0.3.0/skfiles/Cu-Si.skf
#   inflating: matsci-0.3.0/skfiles/H-Al.skf
#   inflating: matsci-0.3.0/skfiles/H-B.skf
#   inflating: matsci-0.3.0/skfiles/H-C.skf
#   inflating: matsci-0.3.0/skfiles/H-Cu.skf
#   inflating: matsci-0.3.0/skfiles/H-H.skf
#   inflating: matsci-0.3.0/skfiles/H-N.skf
#   inflating: matsci-0.3.0/skfiles/H-Na.skf
#   inflating: matsci-0.3.0/skfiles/H-O.skf
#   inflating: matsci-0.3.0/skfiles/H-P.skf
#   inflating: matsci-0.3.0/skfiles/H-Si.skf
#   inflating: matsci-0.3.0/skfiles/H-Ti.skf
#   inflating: matsci-0.3.0/skfiles/N-B.skf
#   inflating: matsci-0.3.0/skfiles/N-C.skf
#   inflating: matsci-0.3.0/skfiles/N-H.skf
#   inflating: matsci-0.3.0/skfiles/N-N.skf
#   inflating: matsci-0.3.0/skfiles/N-O.skf
#   inflating: matsci-0.3.0/skfiles/N-P.skf
#   inflating: matsci-0.3.0/skfiles/N-Si.skf
#   inflating: matsci-0.3.0/skfiles/N-Ti.skf
#   inflating: matsci-0.3.0/skfiles/Na-Al.skf
#   inflating: matsci-0.3.0/skfiles/Na-Cu.skf
#   inflating: matsci-0.3.0/skfiles/Na-H.skf
#   inflating: matsci-0.3.0/skfiles/Na-Na.skf
#   inflating: matsci-0.3.0/skfiles/Na-O.skf
#   inflating: matsci-0.3.0/skfiles/Na-Si.skf
#   inflating: matsci-0.3.0/skfiles/O-Al.skf
#   inflating: matsci-0.3.0/skfiles/O-B.skf
#   inflating: matsci-0.3.0/skfiles/O-C.skf
#   inflating: matsci-0.3.0/skfiles/O-Cu.skf
#   inflating: matsci-0.3.0/skfiles/O-H.skf
#   inflating: matsci-0.3.0/skfiles/O-N.skf
#   inflating: matsci-0.3.0/skfiles/O-Na.skf
#   inflating: matsci-0.3.0/skfiles/O-O.skf
#   inflating: matsci-0.3.0/skfiles/O-P.skf
#   inflating: matsci-0.3.0/skfiles/O-Si.skf
#   inflating: matsci-0.3.0/skfiles/O-Ti.skf
#   inflating: matsci-0.3.0/skfiles/P-Al.skf
#   inflating: matsci-0.3.0/skfiles/P-C.skf
#   inflating: matsci-0.3.0/skfiles/P-H.skf
#   inflating: matsci-0.3.0/skfiles/P-N.skf
#   inflating: matsci-0.3.0/skfiles/P-O.skf
#   inflating: matsci-0.3.0/skfiles/P-P.skf
#   inflating: matsci-0.3.0/skfiles/P-Si.skf
#   inflating: matsci-0.3.0/skfiles/P-Ti.skf
#   inflating: matsci-0.3.0/skfiles/Si-Al.skf
#   inflating: matsci-0.3.0/skfiles/Si-C.skf
#   inflating: matsci-0.3.0/skfiles/Si-Cu.skf
#   inflating: matsci-0.3.0/skfiles/Si-H.skf
#   inflating: matsci-0.3.0/skfiles/Si-N.skf
#   inflating: matsci-0.3.0/skfiles/Si-Na.skf
#   inflating: matsci-0.3.0/skfiles/Si-O.skf
#   inflating: matsci-0.3.0/skfiles/Si-P.skf
#   inflating: matsci-0.3.0/skfiles/Si-Si.skf
#   inflating: matsci-0.3.0/skfiles/Ti-C.skf
#   inflating: matsci-0.3.0/skfiles/Ti-H.skf
#   inflating: matsci-0.3.0/skfiles/Ti-N.skf
#   inflating: matsci-0.3.0/skfiles/Ti-O.skf
#   inflating: matsci-0.3.0/skfiles/Ti-P.skf
#   inflating: matsci-0.3.0/skfiles/Ti-Ti.skf

# %%
# !pip install -q ase jarvis-tools
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 59.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 141.0 MB/s eta 0:00:00

# %%
import argparse
import os
import shutil
import subprocess
import sys
import textwrap
import json
from pathlib import Path
from ase.io import read, write
from ase.symbols import Symbols
import numpy as np
import matplotlib.pyplot as plt
from jarvis.io.vasp.inputs import Poscar

class DFTBPlusCalculator:
    def __init__(self, dftb_executable, sk_dir, k_mesh, optimise=True,
                 calculate_bandgap=False, calc_dos=True, write_hs=False):
        self.dftb_executable = dftb_executable
        self.sk_dir = sk_dir
        self.k_mesh = k_mesh
        self.optimise = optimise
        self.calculate_bandgap = calculate_bandgap
        self.calc_dos = calc_dos
        self.write_hs = write_hs

    def run(self, cmd, cwd=None, log="run.log"):
        """Run *cmd* in *cwd*, streaming stdout/err to screen & file."""
        print(f" → running: {' '.join(cmd)}")
        print('dir', os.getcwd())
        with open(Path(cwd, log), "a") as fh:
            proc = subprocess.Popen(cmd, cwd=cwd, stdout=subprocess.PIPE,
                                    stderr=subprocess.STDOUT, text=True)
            for line in proc.stdout:
                sys.stdout.write(line)
                fh.write(line)
        if proc.wait() != 0:
            raise RuntimeError(f"Command {' '.join(cmd)} failed.")

    def gen_maxam_from_atoms(self, atoms):
        """Return correct MaxAngularMomentum block (one letter per element)."""
        lmap = {}
        for sym in sorted(set(atoms.get_chemical_symbols())):
            Z = atoms[atoms.get_chemical_symbols().index(sym)].number
            if   Z == 1:                lmap[sym] = "s"            # H
            elif Z <= 10:               lmap[sym] = "p"            # He–Ne (s- and p-SKFs)
            elif Z <= 56:               lmap[sym] = "d"            # transition/block-d
            else:                       lmap[sym] = "f"            # lanthanides/actinides
        return "\n".join(f"{el} = \"{l}\"" for el, l in lmap.items())

    def supercell_folding_block(self, n1, n2, n3, shift=(0.0, 0.0, 0.0)):
        """Return a valid SuperCellFolding string for dftb_in.hsd."""
        mat = f"{n1} 0 0\n 0 {n2} 0\n 0 0 {n3}"
        sh  = f"{shift[0]} {shift[1]} {shift[2]}"
        return f"{mat}\n {sh}"

    def dict_to_hsd(self, d, indent=0, top_level_key=None):
        """Convert a nested dictionary to HSD format, top-level key can be block (no `=`)."""
        lines = []
        prefix = "  " * indent

        if top_level_key:
            lines.append(f"{top_level_key} {{")
            indent += 1
            prefix = "  " * indent

        for key, value in d.items():
            if isinstance(value, dict):
                lines.append(f"{prefix}{key} = {{")
                lines.extend(self.dict_to_hsd(value, indent + 1))
                lines.append(f"{prefix}}}")
            elif isinstance(value, list):
                lines.append(f"{prefix}{key} = [")
                for item in value:
                    if isinstance(item, dict):
                        lines.append(f"{prefix}  {{")
                        lines.extend(self.dict_to_hsd(item, indent + 2))
                        lines.append(f"{prefix}  }}")
                    else:
                        lines.append(f"{prefix}  {item}")
                lines.append(f"{prefix}]")
            else:
                lines.append(f"{prefix}{key} = {value}")

        if top_level_key:
            lines.append("}")

        return lines

    def write_hsd(self, fname, geometry_ref, maxl_block):
        # Geometry block
        geometry_block = f"""Geometry = GenFormat {{
    <<< {geometry_ref}
}}"""

        # Driver block
        driver_lines = []
        if self.optimise:
            driver_dict = {
                "GeometryOptimization": {
                    "Optimizer": "Rational {}",
                    "MovedAtoms": "1:-1",
                    "MaxSteps": 100,
                    "OutputPrefix": '"geom.out"',
                    "Convergence": {
                        "GradElem": "1E-4"
                    }
                }
            }
            driver_lines = self.dict_to_hsd(driver_dict, top_level_key="Driver")

        # MaxAngularMomentum and KPoints (raw blocks)
        maxl_block_str = f"""  MaxAngularMomentum = {{
{maxl_block}
}}"""

        kfold_block_str = f"""  KPointsAndWeights = SuperCellFolding {{
    {self.supercell_folding_block(*self.k_mesh)}
}}"""

        # Hamiltonian block
        hamiltonian_dict = {
            "SCC": "Yes",
            "Filling": {
                "Fermi": {
                    "Temperature [Kelvin]": 100
                }
            },
            "SlaterKosterFiles": {
                "Type2FileNames": {
                    "Prefix": f'"{self.sk_dir}/"',
                    "Separator": '"-"',
                    "Suffix": '".skf"'
                }
            }
        }

        # Analysis block (always include CalculateForces)
        analysis_dict = {
            "CalculateForces": "Yes"
        }

        if self.calc_dos:
            analysis_dict["ProjectStates"] = {
                "Region": {
                    "Atoms": "1:-1",
                    "OrbitalResolved": "No"
                }
            }

        if self.calculate_bandgap:
            analysis_dict["BandStructure"] = {
                "OutputKpoints": "Yes",
                "BandLines": {
                    "BrillouinZone": {
                        "SpecialPoints": {
                            "Gamma": "[ 0.0 0.0 0.0 ]",
                            "X": "[ 0.5 0.0 0.0 ]",
                            "L": "[ 0.5 0.5 0.5 ]",
                            "W": "[ 0.5 0.25 0.75 ]",
                            "K": "[ 0.375 0.375 0.75 ]"
                        },
                        "Lines": [
                            {"From": "Gamma", "To": "X", "Points": 20},
                            {"From": "X", "To": "L", "Points": 20},
                            {"From": "L", "To": "Gamma", "Points": 20},
                            {"From": "Gamma", "To": "W", "Points": 20},
                            {"From": "W", "To": "K", "Points": 20}
                        ]
                    }
                }
            }

        analysis_lines = self.dict_to_hsd(analysis_dict, top_level_key="Analysis")

        # Options block
        options_dict = {
            "Options": {
                "WriteResultsTag": "Yes"
            }
        }
        if self.write_hs:
            options_dict["Options"]["WriteHS"] = "Yes"

        # ParserOptions block
        parser_options = {
            "ParserOptions": {
                "ParserVersion": 12
            }
        }

        # Final assembly
        hsd_lines = []
        hsd_lines.append(geometry_block)
        hsd_lines.extend(driver_lines)

        hsd_lines.append("Hamiltonian = DFTB {")
        hsd_lines.extend(self.dict_to_hsd(hamiltonian_dict, indent=1))
        hsd_lines.append(maxl_block_str)
        hsd_lines.append(kfold_block_str)
        hsd_lines.append("}")

        hsd_lines.extend(analysis_lines)
        hsd_lines.extend(self.dict_to_hsd(options_dict))
        hsd_lines.extend(self.dict_to_hsd(parser_options))

        with open(fname, "w") as f:
            f.write("\n".join(hsd_lines) + "\n")

    def get_energy(self, path="detailed.out"):
        with open(path) as f:
            for line in f:
                if "Total energy:" in line:
                    return float(line.split()[-2]) * 27.2114

    def get_forces(self, path="detailed.out"):
        forces = []
        with open(path) as f:
            lines = f.readlines()
            for i, line in enumerate(lines):
                if "Total Forces" in line:
                    for l in lines[i+2:]:
                        if not l.strip():
                            break
                        parts = l.split()
                        forces.append([float(x) * 51.422086 for x in parts[-3:]])
                    break
        return np.array(forces)

    def read_band_out(self, file_path):
        """Read band structure data from band.out file."""
        with open(file_path, 'r') as f:
            lines = f.readlines()

        data = []
        for line in lines:
            if line.strip().startswith('KPT') or line.strip() == '':
                continue
            try:
                data.append([float(x) for x in line.split()])
            except ValueError:
                break

        data = np.array(data)
        k_points = data[:, 0]
        energies = data[:, 1:]
        return k_points, energies

    def gaussian(self, x, mu, sigma):
        """Gaussian function for broadening."""
        return np.exp(-((x - mu) / sigma)**2 / 2) / (sigma * np.sqrt(2 * np.pi))

    def calculate_dos(self, energies, sigma, energy_range, num_points):
        """Calculate density of states using Gaussian broadening."""
        dos = np.zeros(num_points)
        energies_flat = energies.flatten()
        energy_grid = np.linspace(energy_range[0], energy_range[1], num_points)
        for energy in energies_flat:
            dos += self.gaussian(energy_grid, energy, sigma)
        return energy_grid, dos

    def get_bandgap(self, path="band.out"):
        k_points, energies = self.read_band_out(path)
        # Simple bandgap calculation, might need to be adjusted
        vbmax = np.max(energies[:, :energies.shape[1]//2])
        cbmin = np.min(energies[:, energies.shape[1]//2:])
        return cbmin - vbmax, cbmin, vbmax

    def run_dftb(self, atoms, optdir):
        if not os.path.exists(optdir):
            os.mkdir(optdir)

        cwd = os.getcwd()
        my_cwd = os.getcwd()
        os.chdir(cwd)
        write(optdir + "/geo.gen", atoms, format="gen")
        maxl_block = self.gen_maxam_from_atoms(atoms)
        self.write_hsd(optdir + "/dftb_in.hsd", "geo.gen", maxl_block)
        self.run([self.dftb_executable], cwd=optdir)
        os.chdir(my_cwd)

        # Postprocessing
        final_atoms = read(optdir + "/geom.out.gen", format="gen")
        energy = self.get_energy(path=optdir + "/detailed.out")
        forces = self.get_forces(path=optdir + "/detailed.out")

        # Calculate DOS
        if self.calc_dos:
            k_points, energies = self.read_band_out(optdir + "/band.out")
            sigma = 0.1  # eV, broadening parameter
            energy_range = (-5, 5)  # eV, energy range for DOS
            num_points = 1000  # number of points in the DOS energy grid
            energy_grid, dos = self.calculate_dos(energies, sigma, energy_range, num_points)

            # Calculate bandgap
            bandgap, cbm, vbm = self.get_bandgap(path=optdir + "/band.out")

            # Save results to out.json
            results = {
                "energy": energy,
                "forces": forces.tolist(),
                "dos": {"energy_grid": energy_grid.tolist(), "dos": dos.tolist()},
                "bandgap": bandgap,
                "cbm": cbm,
                "vbm": vbm
            }
            with open(optdir + "/out.json", "w") as f:
                json.dump(results, f, indent=4)

        return final_atoms, energy, forces

def main():
    poscar_string = """Silicon
    1.0
    5.3 0.0 0.0
    0.0 5.3 0.0
    0.0 0.0 5.3
    Si
    8
    direct
    0.25 0.75 0.25 Si
    0.0 0.0 0.5 Si
    0.25 0.25 0.75 Si
    0.0 0.5 0.0 Si
    0.75 0.75 0.75 Si
    0.5 0.0 0.0 Si
    0.75 0.25 0.25 Si
    0.5 0.5 0.5 Si
    """
    #poscar_path = 'POSCAR'
    atoms = Poscar.from_string(poscar_string).atoms
    atoms = atoms.ase_converter()

    dftb_executable = "/usr/local/bin/dftb+"
    sk_dir = os.path.abspath("/content/matsci-0.3.0/skfiles/")
    k_mesh = [4, 4, 4]
    optdir = "1_opt"

    calculator = DFTBPlusCalculator(dftb_executable, sk_dir, k_mesh)
    final_atoms, energy, forces = calculator.run_dftb(atoms, optdir)
    print("Energy (eV):", energy)
    print("Forces (eV/Å):", forces)

if __name__ == "__main__":
    main()
# Out:
#  → running: /usr/local/bin/dftb+
# dir /content
# |===============================================================================
# |
# |  DFTB+ release 24.1
# |
# |  Copyright (C) 2006 - 2024  DFTB+ developers group
# |
# |===============================================================================
# |
# |  When publishing results obtained with DFTB+, please cite the following
# |  reference:
# |
# |  * DFTB+, a software package for efficient approximate density functional
# |    theory based atomistic simulations, J. Chem. Phys. 152, 124101 (2020).
# |    [doi: 10.1063/1.5143190]
# |
# |  You should also cite additional publications crediting the parametrization
# |  data you use. Please consult the documentation of the SK-files for the
# |  references.
# |
# |===============================================================================
#
# Reading input file 'dftb_in.hsd'
# Parser version: 14
#
# --------------------------------------------------------------------------------
# ***  Converting input from parser version 12 to parser version 14 ...
# WARNING!
# -> Keyword renamed to 'PrintForces'.
# Path: dftbplusinput/Analysis/CalculateForces
# Line: 40-40 (File: dftb_in.hsd)
#
# ***  Done.
#
# Reading SK-files:
# /content/matsci-0.3.0/skfiles/Si-Si.skf
# Done.
#
#
# Processed input in HSD format written to 'dftb_pin.hsd'
#
# Starting initialization...
# --------------------------------------------------------------------------------
# WARNING!
# -> Dipole printed for extended system : value printed is not well defined
# OpenMP threads:              2
# Chosen random seed:          620864
# Current stacksize:           8 [Mb] (recommended: unlimited)
# WARNING!
# -> Current stacksize not set to unlimited or hard limit, which might cause
#    random crashes (e.g. segmentation faults). It is advised to unlimit the
#    stacksize by issuing 'ulimit -s unlimited' (Linux) or setting it to the
#    hard limit by 'ulimit -s hard' (Mac) in advance.
# Mode:                        Static calculation
# Self consistent charges:     Yes
# SCC-tolerance:                 0.100000E-04
# Max. scc iterations:                    100
# Shell resolved Hubbard:      No
# Spin polarisation:           No
# Nr. of up electrons:            16.000000
# Nr. of down electrons:          16.000000
# Periodic boundaries:         Yes
# Electronic solver:           Relatively robust
# Mixer:                       Broyden mixer
# Mixing parameter:                  0.200000
# Maximal SCC-cycles:                     100
# Nr. of chrg. vec. in memory:            100
# Electronic temperature:              0.316682E-03 H      0.861734E-02 eV
# Initial charges:             Set automatically (system chrg:   0.000E+00)
# Included shells:            Si:  s, p, d
# K-points and weights:           1:  0.000000  0.000000  0.000000     0.015625
#                                 2:  0.000000  0.000000  0.250000     0.031250
#                                 3:  0.000000  0.000000  0.500000     0.015625
#                                 4:  0.000000  0.250000  0.000000     0.031250
#                                 5:  0.000000  0.250000  0.250000     0.031250
#                                 6:  0.000000  0.250000  0.500000     0.031250
#                                 7:  0.000000  0.250000  0.750000     0.031250
#                                 8:  0.000000  0.500000  0.000000     0.015625
#                                 9:  0.000000  0.500000  0.250000     0.031250
#                                10:  0.000000  0.500000  0.500000     0.015625
#                                11:  0.250000  0.000000  0.000000     0.031250
#                                12:  0.250000  0.000000  0.250000     0.031250
#                                13:  0.250000  0.000000  0.500000     0.031250
#                                14:  0.250000  0.000000  0.750000     0.031250
#                                15:  0.250000  0.250000  0.000000     0.031250
#                                16:  0.250000  0.250000  0.250000     0.031250
#                                17:  0.250000  0.250000  0.500000     0.031250
#                                18:  0.250000  0.250000  0.750000     0.031250
#                                19:  0.250000  0.500000  0.000000     0.031250
#                                20:  0.250000  0.500000  0.250000     0.031250
#                                21:  0.250000  0.500000  0.500000     0.031250
#                                22:  0.250000  0.500000  0.750000     0.031250
#                                23:  0.250000  0.750000  0.000000     0.031250
#                                24:  0.250000  0.750000  0.250000     0.031250
#                                25:  0.250000  0.750000  0.500000     0.031250
#                                26:  0.250000  0.750000  0.750000     0.031250
#                                27:  0.500000  0.000000  0.000000     0.015625
#                                28:  0.500000  0.000000  0.250000     0.031250
#                                29:  0.500000  0.000000  0.500000     0.015625
#                                30:  0.500000  0.250000  0.000000     0.031250
#                                31:  0.500000  0.250000  0.250000     0.031250
#                                32:  0.500000  0.250000  0.500000     0.031250
#                                33:  0.500000  0.250000  0.750000     0.031250
#                                34:  0.500000  0.500000  0.000000     0.015625
#                                35:  0.500000  0.500000  0.250000     0.031250
#                                36:  0.500000  0.500000  0.500000     0.015625
#
# K-points in absolute space:     1:  0.000000  0.000000  0.000000
#                                 2:  0.000000  0.000000  0.024961
#                                 3:  0.000000  0.000000  0.049922
#                                 4:  0.000000  0.024961  0.000000
#                                 5:  0.000000  0.024961  0.024961
#                                 6:  0.000000  0.024961  0.049922
#                                 7:  0.000000  0.024961  0.074884
#                                 8:  0.000000  0.049922  0.000000
#                                 9:  0.000000  0.049922  0.024961
#                                10:  0.000000  0.049922  0.049922
#                                11:  0.024961  0.000000  0.000000
#                                12:  0.024961  0.000000  0.024961
#                                13:  0.024961  0.000000  0.049922
#                                14:  0.024961  0.000000  0.074884
#                                15:  0.024961  0.024961  0.000000
#                                16:  0.024961  0.024961  0.024961
#                                17:  0.024961  0.024961  0.049922
#                                18:  0.024961  0.024961  0.074884
#                                19:  0.024961  0.049922  0.000000
#                                20:  0.024961  0.049922  0.024961
#                                21:  0.024961  0.049922  0.049922
#                                22:  0.024961  0.049922  0.074884
#                                23:  0.024961  0.074884  0.000000
#                                24:  0.024961  0.074884  0.024961
#                                25:  0.024961  0.074884  0.049922
#                                26:  0.024961  0.074884  0.074884
#                                27:  0.049922  0.000000  0.000000
#                                28:  0.049922  0.000000  0.024961
#                                29:  0.049922  0.000000  0.049922
#                                30:  0.049922  0.024961  0.000000
#                                31:  0.049922  0.024961  0.024961
#                                32:  0.049922  0.024961  0.049922
#                                33:  0.049922  0.024961  0.074884
#                                34:  0.049922  0.049922  0.000000
#                                35:  0.049922  0.049922  0.024961
#                                36:  0.049922  0.049922  0.049922
#
# Extra options:
#                              Mulliken analysis
#                              Force calculation
# Force type                   original
#
# --------------------------------------------------------------------------------
#
# ***  Geometry step: 0
#
#  iSCC Total electronic   Diff electronic      SCC error
#     1    0.00000000E+00    0.00000000E+00    0.79936058E-14
#
# Total Energy:                      -11.0557944835 H         -300.8435 eV
# Extrapolated to 0K:                -11.0557944835 H         -300.8435 eV
# Total Mermin free energy:          -11.0557944835 H         -300.8435 eV
# Force related energy:              -11.0557944835 H         -300.8435 eV
#
# Volume:                              0.100467E+04 au^3   0.148877E+03 A^3
# Pressure:                           -0.122580E-02 au    -0.360643E+11 Pa
# >> Charges saved for restart in charges.bin
#
# total energy  -1.1055794E+01 H       energy change -1.1055794E+01 H
# gradient norm  2.4998404E-12 H/a0    max. gradient  1.1387180E-12 H/a0
# step length    0.0000000E+00 a0      max. step      0.0000000E+00 a0
#
# Geometry converged
#
# --------------------------------------------------------------------------------
# DFTB+ running times                          cpu [s]             wall clock [s]
# --------------------------------------------------------------------------------
# Pre-SCC initialisation                 +       0.15 (  3.9%)       0.08 (  4.0%)
# SCC                                    +       1.86 ( 49.5%)       0.97 ( 49.7%)
# Post-SCC processing                    +       1.62 ( 43.2%)       0.83 ( 42.7%)
# Post-geometry optimisation             +       0.01 (  0.3%)       0.01 (  0.3%)
# --------------------------------------------------------------------------------
# Missing                                +       0.11 (  3.0%)       0.06 (  3.3%)
# Total                                  =       3.76 (100.0%)       1.96 (100.0%)
# --------------------------------------------------------------------------------
# Energy (eV): -8186.3728159
# Forces (eV/Å): [[-0.0000000e+00 -0.0000000e+00 -5.1422086e-11]
#  [-0.0000000e+00 -0.0000000e+00  5.1422086e-11]
#  [-0.0000000e+00 -5.1422086e-11 -0.0000000e+00]
#  [ 0.0000000e+00  0.0000000e+00  0.0000000e+00]
#  [-5.1422086e-11 -0.0000000e+00 -0.0000000e+00]
#  [ 5.1422086e-11 -0.0000000e+00 -0.0000000e+00]
#  [ 0.0000000e+00  0.0000000e+00  0.0000000e+00]]

# %%
from jarvis.db.jsonutils import loadjson
d=loadjson('1_opt/out.json')

# %%
import matplotlib.pyplot as plt
plt.plot(np.array(d['dos']['energy_grid'])--0.1491610531,d['dos']['dos'])

# %%
d['bandgap']
# Out:
# -18.235

# %%
d.keys()
# Out:
# dict_keys(['energy', 'forces', 'dos', 'bandgap', 'cbm', 'vbm'])
